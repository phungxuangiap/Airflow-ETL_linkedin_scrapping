# %%
from selenium import webdriver;
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time
import uuid
from google import genai
from utils.html_formatter import html_formatter
from dotenv import load_dotenv
import os

load_dotenv()
GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')
LIST_OBJECTS = os.getenv("LIST_OBJECTS")
USER_NAME = os.getenv('USER_NAME')
PASSWORD = os.getenv('PASSWORD')
FORMAT_FOR_THE_PREVIEW = os.getenv('FORMAT_FOR_THE_PREVIEW')
FORMAT_FOR_THE_DETAIL = os.getenv('FORMAT_FOR_THE_DETAIL')

print(GEMINI_API_KEY)
print(LIST_OBJECTS)
print(USER_NAME)
print(PASSWORD)


driver = webdriver.Chrome()
driver.get("https://www.linkedin.com/uas/login")
driver.find_element(By.ID, "username").send_keys(USER_NAME)
driver.find_element(By.ID, "password").send_keys(PASSWORD)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.implicitly_wait(10)
# Out:
# AIzaSyCDRyvWnGVuDyl6U57zgCOtr59NuDEncug
# [{'name': 'Linkedin', 'login_url': "https://www.linkedin.com/uas/login", 'list_job_url': 'https://www.linkedin.com/jobs/collections/recommended/?currentJobId=4325205057&discover=recommended&start=24'}]
# useraccount1@gmail.com
# useraccount123

# %%
driver.get("https://www.linkedin.com/jobs/collections/recommended/?currentJobId=4325205057&discover=recommended&start=24")

# %%
first_job = driver.find_element(By.CSS_SELECTOR, "li.ember-view")

job_list = driver.execute_script("""
    let el = arguments[0];
    while (el.parentElement) {
        el = el.parentElement;
        const style = window.getComputedStyle(el);
        if ((style.overflowY === 'scroll' || style.overflowY === 'auto') && 
            el.scrollHeight > el.clientHeight) {
            return el;
        }
    }
    return null;
""", first_job)


scroll_pause = 0.5 
scroll_increment = 300 
current_scroll = 0

while True:
    scroll_info = driver.execute_script("""
        return {
            scrollTop: arguments[0].scrollTop,
            scrollHeight: arguments[0].scrollHeight,
            clientHeight: arguments[0].clientHeight
        };
    """, job_list)
    
    current_position = scroll_info['scrollTop']
    max_scroll = scroll_info['scrollHeight'] - scroll_info['clientHeight']
    
    if current_position >= max_scroll - 10:  
        break
    
    driver.execute_script(f"arguments[0].scrollTop += {scroll_increment}", job_list)
    time.sleep(scroll_pause)

html_content = driver.page_source

soup = BeautifulSoup(html_content, 'html.parser')

li_elements = soup.find_all('li', class_='ember-view')

# %%
client = genai.Client(api_key=GEMINI_API_KEY)
format_for_the_preview = FORMAT_FOR_THE_PREVIEW
format_for_the_detail = FORMAT_FOR_THE_DETAIL
list_result = []
def scrap_html(output: str, input: str):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=f'''
        OUTPUT FORMAT: {output}
        INPUT: {input}
        ''')
    return response.text
for index, li_element in enumerate(li_elements):
    html_format_final = scrap_html(input = html_formatter(str(li_element)), output=format_for_the_preview)
    print(html_format_final)
    list_result.append(html_format_final)
    if index % 5 == 0:
        time.sleep(10)
# Out:
# job_details.job_title:"Java Fullstack Developer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:""|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City Metropolitan Area"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:""|job_details.view_status:"Viewed"|company_details.name:"SAP"
# job_details.job_title:"Software Engineer Intern - Backend"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:""|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City Metropolitan Area"|job_details.location.workplace_type:"On-site"|job_details.application.method:""|job_details.view_status:""|company_details.name:"ShopBack"
# job_details.job_title:"Mechatronics junior"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"EyeQ Tech"
# job_details.job_title:"Android Engineer (Kotlin)"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:""|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"TymeX"
# job_details.job_title:"ServiceNow QA/Test Engineer"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"Be an early applicant"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:""|job_details.application.method:""|job_details.view_status:""|company_details.name:"DXC Technology"
# job_details.job_title:"Power Platform - D365 FO Engineer"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"Be an early applicant"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:""|job_details.view_status:""|company_details.name:"Discova"
# job_details.job_title:"Junior QA Engineer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"MTI Technology"
# job_details.job_title:"AI/ML Architect - Vietnam Remotely"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"An Giang, Vietnam"|job_details.location.workplace_type:"Remote"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"Rackspace Technology"
# job_details.job_title:"Vision System Principal Engineer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"Milwaukee Tool"
# job_details.job_title:"Senior Java Developer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:"Be an early applicant"|company_details.name:"Simpson Strong-Tie Vietnam"
# job_details.job_title:"Mid/Senior Fullstack Engineer (JavaScript, NodeJS) (2 openings) - Hybrid working model"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"SMG Vietnam"
# job_details.job_title:"Full Stack Engineer"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:""|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:""|job_details.application.method:""|job_details.view_status:""|company_details.name:"WorldQuant"
# job_details.job_title:"Test Development Engineer Intern"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:""|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:""|job_details.application.method:""|job_details.view_status:""|company_details.name:"NVIDIA"
# job_details.job_title:"C/C++ Developer (All Levels)"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:"Be an early applicant"|company_details.name:"FPT Software Career"
# job_details.job_title:"Python Developer"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:"Easy Apply"|job_details.view_status:"Be an early applicant"|company_details.name:"LARION"
# job_details.job_title:"Senior Software Engineer - Seller Center"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"early_applicant"|job_details.status.promotion_status:"promoted"|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:""|job_details.view_status:""|company_details.name:"Global Fashion Group"
# job_details.job_title:"Senior Unity Developer (Playable Ads)"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:""|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"52 Entertainment"
# job_details.job_title:"Software Engineer C++"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Be an early applicant"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"MiTek Vietnam"
# job_details.job_title:"Software Engineer (Middle Level)"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:"Promoted"|job_details.location.city_country:"Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"Trivita AI"
# job_details.job_title:"(JavaScript) Junior Fullstack Developer"|job_details.job_url:""|job_details.status.verified:true|job_details.status.reviewing_status:""|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:""|job_details.view_status:""|company_details.name:"Sunbytes"
# job_details.job_title:"Java Developer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:""|job_details.status.promotion_status:""|job_details.location.city_country:"District 3, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:""|job_details.view_status:""|company_details.name:"GSOFT"
# job_details.job_title:"Software Engineer Intern"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:""|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"Hybrid"|job_details.application.method:""|job_details.view_status:""|company_details.name:"Upskills"
# job_details.job_title:"Junior Frontend ReactJS Developer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:""|job_details.status.promotion_status:""|job_details.location.city_country:"Ho Chi Minh City Metropolitan Area"|job_details.location.workplace_type:"Remote"|job_details.application.method:""|job_details.view_status:""|company_details.name:"Kegmil"
# job_details.job_title:"Game Frontend Engineer"|job_details.job_url:""|job_details.status.verified:false|job_details.status.reviewing_status:"Actively reviewing applicants"|job_details.status.promotion_status:""|job_details.location.city_country:"Tân Bình, Ho Chi Minh City, Vietnam"|job_details.location.workplace_type:"On-site"|job_details.application.method:"Easy Apply"|job_details.view_status:""|company_details.name:"Tinhvan Software JSC."
