# %%
sample_data = [
  {
    "title": "Senior Python Developer",
    "company": "TechNova Solutions",
    "company_avatar_url": "https://logo.clearbit.com/technova.io",
    "company_location": "Ho Chi Minh City, Vietnam",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "45 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1001",
    "description": "We are looking for a Python expert to scale our microservices..."
  },
  {
    "title": "Data Engineer",
    "company": "DataFlow Systems",
    "company_avatar_url": "https://logo.clearbit.com/dataflow.com",
    "company_location": "Hanoi, Vietnam",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2025-12-30",
    "number_applicants": "12 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1002",
    "description": "Build robust ETL pipelines using Spark and Airflow."
  },
  {
    "title": "Frontend Architect",
    "company": "WebCore",
    "company_avatar_url": "https://logo.clearbit.com/webcore.net",
    "company_location": "Singapore",
    "location_working_type": "Remote",
    "working_type": "Contract",
    "date_posted": "2026-01-02",
    "number_applicants": "89 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1003",
    "description": "Lead the transition from React to Next.js 16."
  },
  {
    "title": "AI Research Scientist",
    "company": "NeuralMind",
    "company_avatar_url": '',
    "company_location": "San Francisco, CA",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "210 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1004",
    "description": "Developing next-gen LLMs for autonomous agents."
  },
  {
    "title": "DevOps Engineer",
    "company": "CloudScale",
    "company_avatar_url": "https://logo.clearbit.com/cloudscale.io",
    "company_location": "Austin, TX",
    "location_working_type": "Remote",
    "working_type": "Full-time",
    "date_posted": "2025-12-28",
    "number_applicants": "34 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1005",
    "description": "Manage Kubernetes clusters on GCP and AWS."
  },
  {
    "title": "Backend Engineer (Go)",
    "company": "FinTech Alpha",
    "company_avatar_url": "https://logo.clearbit.com/fintechalpha.com",
    "company_location": "London, UK",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2025-12-31",
    "number_applicants": "56 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1006",
    "description": "Secure payment processing systems using Golang."
  },
  {
    "title": "Product Designer",
    "company": "Creative Studio",
    "company_avatar_url": '',
    "company_location": "Berlin, Germany",
    "location_working_type": "Remote",
    "working_type": "Part-time",
    "date_posted": "2026-01-02",
    "number_applicants": "15 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1007",
    "description": "UI/UX design for a new fashion e-commerce platform."
  },
  {
    "title": "Cybersecurity Analyst",
    "company": "SafeGuard IT",
    "company_avatar_url": "https://logo.clearbit.com/safeguard.com",
    "company_location": "Toronto, Canada",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "27 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1008",
    "description": "Monitor networks for security breaches and respond to incidents."
  },
  {
    "title": "MLOps Engineer",
    "company": "AutoAI",
    "company_avatar_url": "https://logo.clearbit.com/autoai.ai",
    "company_location": "Tokyo, Japan",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2025-12-25",
    "number_applicants": "18 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1009",
    "description": "Bridge the gap between ML models and production."
  },
  {
    "title": "Mobile Lead (Flutter)",
    "company": "AppNation",
    "company_avatar_url": '',
    "company_location": "Bangkok, Thailand",
    "location_working_type": "Remote",
    "working_type": "Full-time",
    "date_posted": "2026-01-02",
    "number_applicants": "42 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1010",
    "description": "Lead mobile development for a million-user social app."
  },
  {
    "title": "Blockchain Developer",
    "company": "CryptoFlow",
    "company_avatar_url": "https://logo.clearbit.com/cryptoflow.io",
    "company_location": "Remote",
    "location_working_type": "Remote",
    "working_type": "Contract",
    "date_posted": "2025-12-29",
    "number_applicants": "105 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1011",
    "description": "Writing smart contracts in Solidity for DeFi protocols."
  },
  {
    "title": "Marketing Specialist",
    "company": "GrowthHub",
    "company_avatar_url": "https://logo.clearbit.com/growthhub.com",
    "company_location": "New York, NY",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "67 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1012",
    "description": "SEO, SEM, and social media growth strategies."
  },
  {
    "title": "Solutions Architect",
    "company": "Enterprise Solutions",
    "company_avatar_url": '',
    "company_location": "Paris, France",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "22 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1013",
    "description": "Designing scalable infrastructure for Fortune 500s."
  },
  {
    "title": "QA Automation Engineer",
    "company": "TestMasters",
    "company_avatar_url": "https://logo.clearbit.com/testmasters.com",
    "company_location": "Pune, India",
    "location_working_type": "Remote",
    "working_type": "Full-time",
    "date_posted": "2025-12-27",
    "number_applicants": "9 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1014",
    "description": "Building automated test suites using Playwright."
  },
  {
    "title": "Data Scientist",
    "company": "Insight Corp",
    "company_avatar_url": "https://logo.clearbit.com/insight.com",
    "company_location": "Sydney, Australia",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2026-01-02",
    "number_applicants": "130 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1015",
    "description": "Extracting business value from large customer datasets."
  },
  {
    "title": "Rust Engineer",
    "company": "SpeedSystems",
    "company_avatar_url": '',
    "company_location": "Stockholm, Sweden",
    "location_working_type": "Remote",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "54 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1016",
    "description": "Rewriting core performance modules in Rust."
  },
  {
    "title": "Site Reliability Engineer",
    "company": "Uptime Inc",
    "company_avatar_url": "https://logo.clearbit.com/uptime.io",
    "company_location": "Dublin, Ireland",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2025-12-30",
    "number_applicants": "31 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1017",
    "description": "Ensuring 99.99% availability for our SaaS platform."
  },
  {
    "title": "Fullstack Developer",
    "company": "Startup Studio",
    "company_avatar_url": '',
    "company_location": "Seoul, South Korea",
    "location_working_type": "On-site",
    "working_type": "Full-time",
    "date_posted": "2026-01-02",
    "number_applicants": "48 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1018",
    "description": "Building a stealth-mode healthcare platform."
  },
  {
    "title": "Technical Writer",
    "company": "DocuTech",
    "company_avatar_url": "https://logo.clearbit.com/docutech.com",
    "company_location": "Remote",
    "location_working_type": "Remote",
    "working_type": "Part-time",
    "date_posted": "2025-12-20",
    "number_applicants": "14 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1019",
    "description": "Creating API documentation for developers."
  },
  {
    "title": "Engineering Manager",
    "company": "Giant Retail",
    "company_avatar_url": "https://logo.clearbit.com/giant.com",
    "company_location": "Seattle, WA",
    "location_working_type": "Hybrid",
    "working_type": "Full-time",
    "date_posted": "2026-01-01",
    "number_applicants": "76 applicants",
    "job_url": "https://www.linkedin.com/jobs/view/1020",
    "description": "Managing a team of 15 backend engineers."
  }
]
